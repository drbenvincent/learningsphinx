# %% [markdown]
# # Example 1
#
#
# $$
# y = m x + c
# $$

# %%
print(2 + 2)
# Out:
# 4

# %% [markdown]
# ## Subsection 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100
x = np.linspace(0, 100, N)
y = np.sin(x/5) + np.random.normal(size=N) * 0.1

plt.plot(x, y);

# %% [markdown]
# ## Subsection 2

# %%
2 + 2
# Out:
# 4
